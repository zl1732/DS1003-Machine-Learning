# %%
import torch
import pickle

# %%
f = open('model_winSize4.pt','rb')
model = torch.load(f)
f.close()
model.cpu()
# Out:
# RNNModel (
#   (drop): Dropout (p = 0.2)
#   (encoder): Embedding(10002, 512)
#   (rnn): LSTM(512, 512, num_layers=2, dropout=0.2)
#   (decoder): Linear (512 -> 10002)
# )

# %%
f = open('model_winSize4_cpu.pt','wb')
torch.save(f=f,obj=model)
f.close()
